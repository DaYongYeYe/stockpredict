# %%
#  从数据读取原始数据

#  设置日期列为索引

#  使用ARIMA 预测股票数据


#  使用LSTM 预测

#  使用prophet 预测


#  分别将预测的数据写入数据库

# %%
import pandas as pd
import pymysql
import numpy as np
from sqlalchemy import create_engine

# 初始化数据库连接
pymysql.install_as_MySQLdb()

# 设置连接路径
DB_STRING='mysql+mysqlconnector://root:123456@127.0.0.1:3306/stock?charset=utf8'

engine=create_engine(DB_STRING)
engine.connect()


#  一次性全部出来 使用 

#  使用sql 语句将 所有的code 放入list 集合中

# %%
code=str(item)
name=pd.read_sql(sql="select name from stocklist where code = '{}'".format(600004),con=engine).to_string().split("  ")[2]
name
# Out:
# '白云机场'

# %%
list=pd.read_sql('select * from stocklist',con=engine)['code'].tolist()

# for item in list:

sql="select * from originstock where code='{}'".format(600004)
df=pd.read_sql(sql=sql,con=engine)
# df
df[['date','close']].set_index('date')
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
import matplotlib.pyplot as plt
model=SimpleExpSmoothing(df['close'])
model_fit=model.fit()
m=model_fit.predict(3650)
m
# Out:
# 3650    30.47
# dtype: float64

# %%
#  使用循环 以60 天的数据 预测数据

list=np.array(df['close'][3540:])
# print(list)
predict_list=[]
for i in range(60):
    model=SimpleExpSmoothing(list)
    pre=model.fit().predict()
    print(pre.tolist()[0])
    predict_list.append(pre.tolist()[0])
    list=np.delete(list,0)
    list=np.append(list,pre.tolist()[0])
predict_list
# Out:
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# ...

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing
list=np.array(df['close'][3540:])
# print(list)
predict_list=[]
for i in range(60):
    model=ExponentialSmoothing(list)
    pre=model.fit().predict()
    print(pre.tolist()[0])
    predict_list.append(pre.tolist()[0])
    list=np.delete(list,0)
    list=np.append(list,pre.tolist()[0])
predict_list
predictDf=pd.DataFrame(predict_list,columns=['predict'])
predictDf['date']= pd.date_range('2022-11-16','2023-1-14',freq='D')
predictDf['predictmethods']='指数平滑'
predictDf['close']=0
predictDf['code']=str(item)
predictDf['name']=name
predictDf
# Out:
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# 30.46999999538064
# ...

# %%
from statsmodels.tsa.ar_model import AutoReg
list=np.array(df['close'][3540:])
predict_list=[]
model=AutoReg(df['close'][:],lags=1)
pre=model.fit().predict(3601,3660)
predictDf=pd.DataFrame(pre,columns=['predict'])
predictDf['date']= pd.date_range('2022-11-16','2023-1-14',freq='D')
predictDf['predictmethods']='自回归'
predictDf['close']=0
predictDf['code']=''
predictDf['name']=name
predictDf
# Out:
# 60
#         predict       date predictmethods  close code  name
# 3601  30.447300 2022-11-16           指数平滑      0       白云机场
# 3602  30.435969 2022-11-17           指数平滑      0       白云机场
# 3603  30.424652 2022-11-18           指数平滑      0       白云机场
# 3604  30.413348 2022-11-19           指数平滑      0       白云机场
# 3605  30.402057 2022-11-20           指数平滑      0       白云机场
# 3606  30.390779 2022-11-21           指数平滑      0       白云机场
# 3607  30.379515 2022-11-22           指数平滑      0       白云机场
# 3608  30.368263 2022-11-23           指数平滑      0       白云机场
# 3609  30.357024 2022-11-24           指数平滑      0       白云机场
# 3610  30.345799 2022-11-25           指数平滑      0       白云机场
# 3611  30.334586 2022-11-26           指数平滑      0       白云机场
# 3612  30.323387 2022-11-27           指数平滑      0       白云机场
# 3613  30.312201 2022-11-28           指数平滑      0       白云机场
# 3614  30.301027 2022-11-29           指数平滑      0       白云机场
# 3615  30.289867 2022-11-30           指数平滑      0       白云机场
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense,LSTM
df_1=pd.DataFrame()
df_1['close']=df['close']
df_1['date']=df['date']
df_1.set_index('date',inplace=True)
df_1

dataset=df_1.values
print(dataset)
training_data_len=3540
print(training_data_len)

scaler=MinMaxScaler(feature_range=(0,1))
scaled_data=scaler.fit_transform(dataset)
scaled_data

train_data=scaled_data[0:int(training_data_len),:]
x_train=[]
y_train=[]
for i in range(60,len(train_data)):
    x_train.append(train_data[i-60:i,0])
    y_train.append(train_data[i,0])
    if i<=61:
        print(x_train)
        print(y_train)
        print()
x_train,y_train=np.array(x_train),np.array(y_train)
x_train=np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))
model =Sequential()
model.add(LSTM(128,return_sequences=True,input_shape=(x_train.shape[1],1)))
model.add(LSTM(64,return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(x_train,y_train,batch_size=1,epochs=1)
test_data=scaled_data[training_data_len-60:,:]
x_test=[]
y_test=dataset[training_data_len:,:]
for i in range(60,len(test_data)):
    x_test.append(test_data[i-60:i,0])
x_test=np.array(x_test)
x_test=np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))
predictions=model.predict(x_test)
predictions=scaler.inverse_transform(predictions)
rmse=np.sqrt(np.mean(((predictions-y_test)**2)))
train=df['close'][:training_data_len]
valid=df['close'][training_data_len:]
valid['predictions']=predictions
valid
# Out:
# [[25.78]
#  [25.29]
#  [23.86]
#  ...
#  [31.99]
#  [30.16]
#  [30.47]]
# 3540
# [array([0.45532831, 0.44214209, 0.40365985, 0.3810549 , 0.40635091,
#        0.41415501, 0.39854682, 0.38293864, 0.38401507, 0.38455328,
#        0.37217438, 0.39181916, 0.43003229, 0.41550054, 0.38832078,
#        0.39693219, 0.38724435, 0.39531755, 0.40715823, 0.39074273,
#        0.38562971, 0.36194833, 0.33584499, 0.34607104, 0.35279871,
#        0.348493  , 0.36141012, 0.36383208, 0.35683531, 0.34364909,
#        0.34634015, 0.35279871, 0.34284177, 0.33638321, 0.30382131,
#        0.29763186, 0.2911733 , 0.27529602, 0.24623251, 0.2664155 ,
#        0.27556512, 0.29547901, 0.26480086, 0.27502691, 0.27341227,
#        0.25188375, 0.25888052, 0.22766416, 0.21878364, 0.21501615,
#        0.2335845 , 0.2704521 , 0.27152853, 0.26184069, 0.27717976,
#        0.27771798, 0.26506997, 0.29467169, 0.282831  , 0.27072121])]
# [0.25188374596340146]
#
# ...

# %%
model.predict()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\users\00\desktop\mathModel\毕业设计\dataPredict.ipynb Cell 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/users/00/desktop/mathModel/%E6%AF%95%E4%B8%9A%E8%AE%BE%E8%AE%A1/dataPredict.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> model.predict()
#
# File c:\Users\00\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# ...
